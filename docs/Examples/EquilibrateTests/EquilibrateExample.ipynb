# %%
import petthermotools as ptt 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

#### uncomment these two lines if alphaMELTS files are not added to your Python path - obviously you're have to change the file location
# import sys
# sys.path.append(r"/Users/gleesonm/Library/CloudStorage/GoogleDrive-gleesonm@berkeley.edu/My Drive/2022/GitHub/MELTS130beta/MacOS")

# %%
# used to suppress MELTS outputs in MacOS systems (run twice)
import platform
if platform.system() == "Darwin":
    import sys
    import os
    sys.stdout = open(os.devnull, 'w')
    sys.stderr = open(os.devnull, 'w')

# %%
bulk = {'SiO2': 53.93,
        'TiO2': 0.67,
        'Al2O3': 18.56,
        'FeOt': 8.5,
        'MnO': 0.21,
        'MgO': 3.96,
        'CaO': 9.16,
        'Na2O': 2.92,
        'K2O': 0.69,
        'P2O5': 0.13}

# %%
Combined = ptt.equilibrate_multi(Model = "MELTSv1.2.0", bulk = bulk, T_C = np.zeros(100) + 1070, # small bug, you have to make sure T_C is the correct size
                      P_bar = 2000, H2O_Liq = np.random.random(100)*10,
                      fO2_buffer="NNO", fO2_offset = 1)
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
Combined
# Out:
#        T_C   P_bar      mass_g           h_J       s_J/K      v_cm3  \
# 0   1070.0  2000.0  100.368752 -1.253196e+06  316.500363  51.785634
# 1   1070.0  2000.0  100.364231 -1.251950e+06  324.704410  55.127755
# 2   1070.0  2000.0  100.364646 -1.252064e+06  323.951899  54.821201
# 3   1070.0  2000.0  100.362134 -1.251372e+06  328.510232  56.678150
# 4   1070.0  2000.0  100.366682 -1.252625e+06  320.255861  53.315529
# ..     ...     ...         ...           ...         ...        ...
# 95  1070.0  2000.0  100.368941 -1.253248e+06  316.157104  51.645799
# 96  1070.0  2000.0  100.430571 -1.265205e+06  269.076815  39.892971
# 97  1070.0  2000.0  100.382297 -1.256755e+06  292.941197  42.567479
# 98  1070.0  2000.0  100.406110 -1.260809e+06  278.420744  40.875292
# 99  1070.0  2000.0  100.370991 -1.253813e+06  312.436439  50.130095
#
#       rho_kg/m3  log10(fO2)  dvdp_cm3/bar   SiO2_Liq  ...  calcite_affinity  \
# 0   1938.158193   -8.200846      0.009852  53.835613  ...               NaN
# 1   1820.575331   -8.200846      0.013599  53.835613  ...               NaN
# 2   1830.763346   -8.200846      0.013256  53.835613  ...               NaN
# 3   1770.737638   -8.200846      0.015338  53.835613  ...               NaN
# 4   1882.503720   -8.200846      0.011567  53.835613  ...               NaN
# ..          ...         ...           ...        ...  ...               ...
# 95  1943.409570   -8.200846      0.009695  53.835613  ...               NaN
# 96  2517.500401   -8.200846     -0.000055  57.446390  ...               NaN
# 97  2358.192217   -8.200846     -0.000285  53.951044  ...               NaN
# 98  2456.401050   -8.200846     -0.000184  55.727302  ...               NaN
# 99  2002.210260   -8.200846      0.007996  53.835613  ...               NaN
#
#     aragonite_affinity  magnesite_affinity  siderite_affinity  \
# 0                  NaN                 NaN                NaN
# 1                  NaN                 NaN                NaN
# 2                  NaN                 NaN                NaN
# 3                  NaN                 NaN                NaN
# 4                  NaN                 NaN                NaN
# ..                 ...                 ...                ...
# 95                 NaN                 NaN                NaN
# 96                 NaN                 NaN                NaN
# 97                 NaN                 NaN                NaN
# 98                 NaN                 NaN                NaN
# 99                 NaN                 NaN                NaN
#
#     dolomite_affinity  spurrite_affinity  tilleyite_affinity  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
# ..                ...                ...                 ...
# 95                NaN                NaN                 NaN
# 96                NaN                NaN                 NaN
# 97                NaN                NaN                 NaN
# 98                NaN                NaN                 NaN
# 99                NaN                NaN                 NaN
#
#     diamond_affinity  graphite_affinity  fluid_affinity
# 0                NaN                NaN             NaN
# 1                NaN                NaN             NaN
# 2                NaN                NaN             NaN
# 3                NaN                NaN             NaN
# 4                NaN                NaN             NaN
# ..               ...                ...             ...
# 95               NaN                NaN             NaN
# 96               NaN                NaN    10774.935064
# 97               NaN                NaN      404.053778
# 98               NaN                NaN     5824.144314
# 99               NaN                NaN             NaN
#
# [100 rows x 503 columns]

# %% [markdown]
# ## Run the same calculation but suppress ALL solids (random H2O and CO2 contents)

# %%
NoSolids = ptt.equilibrate_multi(Model = "MELTSv1.2.0", bulk = bulk, T_C = np.zeros(100) + 1070, P_bar = 500, H2O_Liq = np.random.random(100)*10, 
                                 CO2_Liq = np.random.random(100)*0.4, fO2_buffer = "NNO", fO2_offset = 1, Suppress = "All")
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %%
NoSolids.head()
# Out:
#       T_C  P_bar      mass_g           h_J       s_J/K       v_cm3  \
# 0  1070.0  500.0  100.254600 -1.256091e+06  304.577454   87.080774
# 1  1070.0  500.0  100.259521 -1.257629e+06  288.859280   64.678396
# 2  1070.0  500.0  100.251124 -1.253417e+06  313.958581  101.309312
# 3  1070.0  500.0  100.270951 -1.263519e+06  259.570576   38.818106
# 4  1070.0  500.0  100.259368 -1.258145e+06  289.931991   65.678036
#
#      rho_kg/m3  log10(fO2)  dvdp_cm3/bar   SiO2_Liq  ...  calcite_affinity  \
# 0  1151.282827   -8.200846      0.042256  53.278167  ...               NaN
# 1  1550.123794   -8.200846      0.021620  53.321279  ...               NaN
# 2   989.554879   -8.200846      0.054937  53.293908  ...               NaN
# 3  2583.097461   -8.200846     -0.000259  54.143036  ...               NaN
# 4  1526.528123   -8.200846      0.022674  53.294790  ...               NaN
#
#    aragonite_affinity  magnesite_affinity  siderite_affinity  \
# 0                 NaN                 NaN                NaN
# 1                 NaN                 NaN                NaN
# 2                 NaN                 NaN                NaN
# 3                 NaN                 NaN                NaN
# 4                 NaN                 NaN                NaN
#
#    dolomite_affinity  spurrite_affinity  tilleyite_affinity  diamond_affinity  \
# 0                NaN                NaN                 NaN               NaN
# 1                NaN                NaN                 NaN               NaN
# 2                NaN                NaN                 NaN               NaN
# 3                NaN                NaN                 NaN               NaN
# 4                NaN                NaN                 NaN               NaN
#
#    graphite_affinity  fluid_affinity
# 0                NaN             NaN
# 1                NaN             NaN
# 2                NaN             NaN
# 3                NaN     3801.551219
# 4                NaN             NaN
#
# [5 rows x 209 columns]

# %% [markdown]
# # Run an equilibrate calculation using the Green et al. (2025) thermodynamic model via MAGEMin

# %%
Eq_Green = ptt.equilibrate_multi(Model = "Green2025", bulk = bulk, 
                                 T_C = np.zeros(100) + 1070.0, 
                                 P_bar = 500.0, H2O_Liq = np.random.random(100)*10.0, Fe3Fet_Liq = 0.15)

# %%
Eq_Green
# Out:
#        T_C  P_bar  mass_g           h_J       s_J/K      v_cm3    rho_kg/m3  \
# 0   1070.0  500.0   100.0 -1.273604e+06  311.343899  44.673559  2238.460566
# 1   1070.0  500.0   100.0 -1.277995e+06  287.782958  42.549396  2350.209627
# 2   1070.0  500.0   100.0 -1.273638e+06  311.159462  44.656180  2239.331734
# 3   1070.0  500.0   100.0 -1.283442e+06  258.479733  40.081282  2494.930204
# 4   1070.0  500.0   100.0 -1.276210e+06  297.371029  43.397299  2304.290889
# ..     ...    ...     ...           ...         ...        ...          ...
# 95  1070.0  500.0   100.0 -1.278861e+06  283.140720  42.145331  2372.742057
# 96  1070.0  500.0   100.0 -1.281158e+06  270.780757  41.093038  2433.502239
# 97  1070.0  500.0   100.0 -1.279867e+06  277.743702  41.681354  2399.154309
# 98  1070.0  500.0   100.0 -1.277336e+06  291.309928  42.857593  2333.308817
# 99  1070.0  500.0   100.0 -1.281246e+06  270.322854  41.056013  2435.696835
#
#     log10(fO2)  mass_per_mole_g/mol    eta_Pa.s  ...  TiO2_Opx  Al2O3_Opx  \
# 0    -9.880997            52.411319  185.455835  ...       NaN        NaN
# 1    -9.842001            55.720670  182.694634  ...       NaN        NaN
# 2    -9.878874            52.435765  185.313886  ...       NaN        NaN
# 3    -9.798354            60.470076  178.108425  ...       NaN        NaN
# 4    -9.854117            54.324720  183.692492  ...       NaN        NaN
# ..         ...                  ...         ...  ...       ...        ...
# 95   -9.835499            56.422483  182.232876  ...       NaN        NaN
# 96   -9.817804            58.380991  180.021777  ...       NaN        NaN
# 97   -9.826228            57.260835  181.030259  ...       NaN        NaN
# 98   -9.848377            55.199297  182.794141  ...       NaN        NaN
# 99   -9.816587            58.455702  179.975091  ...       NaN        NaN
#
#     Cr2O3_Opx  FeOt_Opx  MgO_Opx  CaO_Opx  Na2O_Opx  K2O_Opx  H2O_Opx  \
# 0         NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 1         NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 2         NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 3         NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 4         NaN       NaN      NaN      NaN       NaN      NaN      NaN
# ..        ...       ...      ...      ...       ...      ...      ...
# 95        NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 96        NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 97        NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 98        NaN       NaN      NaN      NaN       NaN      NaN      NaN
# 99        NaN       NaN      NaN      NaN       NaN      NaN      NaN
#
#     Fe3Fet_Opx
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 95         NaN
# 96         NaN
# 97         NaN
# 98         NaN
# 99         NaN
#
# [100 rows x 118 columns]

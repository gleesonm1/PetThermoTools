# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pyMELTScalc as M

import sys
sys.path.append(r"/Users/gleesonm/Library/CloudStorage/GoogleDrive-gleesonm@berkeley.edu/My Drive/2022/GitHub/pyMELTScalc/MELTS")

M.__version__
# Out:
# '0.1.28'

# %%
# used to suppress MELTS outputs in MacOS systems (run twice)
import os
sys.stdout = open(os.devnull, 'w')
sys.stderr = open(os.devnull, 'w')

# %%
bulk = M.Compositions['KLB-1']
bulk['K2O_Liq'] = 0.0 # overwrite otherwise MELTS always predicts the presence of a melt phase.

# %%
Results = M.phaseDiagram_calc(Model = "pMELTS", bulk = bulk,
                            P_bar = np.linspace(1000, 50000, 200), 
                            T_C = np.linspace(1100, 1800, 200))

# %%
M.plot_phaseDiagram(Combined = Results)

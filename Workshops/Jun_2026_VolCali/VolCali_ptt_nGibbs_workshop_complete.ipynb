# %% [markdown]
# # VolCali alphaMELTS workshop
#
# Welcome to the notebook for the 2026 VolCali alphaMELTS workshop. In this session we'll be getting to grips with 2 of the newer packages, and approaches, that are part of the alphaMELTS 'family': PetThermoTools and nGibbs. PetThermoTools is a Python front-end to the alphaMELTS for Python and MAGEMin packages (Antoshechkina and Ghiorso, 2018; Riel et al. 2022), providing easy access to thermodynamic modeling within a Python environment with built-in functions for the most common thermodyanmic methods. Within this notebook we'll use PetThermoTools to calculate melt inclusion saturation pressures, examine liquidus phase assemblages, calculate potential crystallization paths, and compare phase diagrams for Mauna Loa and Kilauea volcanic systems. nGibbs is a Machine Learning emulator trained on thermodynamic simulations. One version of nGibbs is trained on rhyolite-MELTS v1.0.2 models, and we will use this emulator to demonstrate how ML can be used to provide a significant speed up in "thermodynamic" calculations.
#
# This workshop will only serve as a brief introduction to both PetThermoTools and nGibbs. If you're interested in learning more ask to join our Discord server and/or check out our documentation and examples over on ReadtheDocs (https://petthermotools.readthedocs.io/en/latest/) and YouTube (https://www.youtube.com/@PetThermoTools). Most importantly, we encourage any users that have not yet done so already to check out our installation instructions: https://www.youtube.com/watch?v=-Mz8CIkbi38&t=3s & https://www.youtube.com/watch?v=yHNiX8P7xXw&t=2s
#
# As with any Python based workshop, let's start by importing the main Python libraries into our environment:

# %%
# %pip install --upgrade torch

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
from time import time

# %% [markdown]
# Let's also import PetThermoTools - if you haven't done so already please install PetThermoTools following the instructions outlined in the videos above - it's also worth checking the version number for PetThermoTools at this point. You should see `v1.0.0` printed when you run the following cell.

# %%
import petthermotools as ptt 

ptt.__version__
# Out:
# alphaMELTS for Python files successfully located.
# If using the Green et al. (2025) or Weller et al. (2024) thermodynamic models please run `ptt.activate_petthermotools_env()` prior to any calculations.
# '1.1.1'

# %% [markdown]
# For most people the previous cell likely printed a message stating
#
# `alphaMELTS for Python files successfully located.`.
#
# If instead you see a message that includes
#
# ```Use `import sys; sys.path.append(r'path_to_alphaMELTS_4_python')` to add the alphaMELTS for Python files to the Python path.```
#
# then you will need to uncomment the two lines below and insert the path to the alphaMELTS for Python files (specifically the folder containing the meltsdynamic.py file) on your machine.

# %%
# import sys
# sys.path.append(f"path_to_meltsdynamic.py")

# %% [markdown]
# # Using nGibbs in PetThermoTools
#
# nGibbs is a neural network machine learning model (https://github.com/benjthyer/nGibbs) that is trained on rhyolite-MELTS 1.0.2 and rhyolite-MELTS 1.2.0.
#
# ## Why use an emulator instead of "the real deal"?
#
# nGibbs is 100s to 1000s of times as fast as MELTS for large jobs. Some problems are much easier to solve when the calculations are fast. For instance, Let's say you have a cumulate rock and you want to identify the composition of its parent magma and the conditions of its crystallization. There's a lot of variables that you may need to explore: Pressure, temperature, oxygen fugacity, water content, SiO2, CaO, Al2O3, CO2, etc etc... You could use a Monte Carlo Markov chain with all of these degrees of freedom, but you would need a very fast model for this to be feasible! This is where nGibbs comes in. Surrogate models like nGibbs are also used for making geodynamic simulations more realistic. A fast model like nGibbs is also useful for broad searches of compositions and conditions in early phases of research in preparation for full thermodynamic calculations.
#
# Although not implemented in PetThermoTools, nGibbs also emulates HeFESTo thermodynamic modelling for subsolidus phase equilibria of the mantle (https://kgblab.epss.ucla.edu/project/hefesto/). Releases coming soon will support pMELTS as well!
#
# This release is a bit of a preview, so please send Ben comments, notice of bugs, suggestions, collaborations, and questions! If nGibbs isn't quite there yet for your specific use, we may be able to train a new model for it. (bthyer@caltech.edu)
#
# One of the coolest things about nGibbs is that it can be used in PetThermoTools very similarly to the other MELTS models, so it should be easy to integrate into your workflows.
#
# For instance, instead of calling
#
# ```
# equil = ptt.equilibrate_multi(Model = "MELTSv1.2.0",
#                             bulk = LL8,
#                             P_bar = Sat_PT['P_bar'].values,
#                             T_C = Sat_PT['T_Liq_C'].values)
# ```
#
# Just put an "n" in front of the Model name: "nMELTSv1.2.0"!
# And optionally add "NoProp" afterwards if you can skip the calculations of the thermodynamic properties (this is useful if you are only interested in phase equilibria: It saves a lot of time.)
#
# This runs the same calculation on the nGibbs emulator of rhyolite-MELTS 1.2.0!
#
# ```
# equil = ptt.equilibrate_multi(Model = "nMELTSv1.2.0", # or Model = "nMELTSv1.2.0NoProp"
#                             bulk = LL8,
#                             P_bar = Sat_PT['P_bar'].values,
#                             T_C = Sat_PT['T_Liq_C'].values)
# ```
#
#
# Thyer, B. J. (2026). nGibbs (Version 0.1.0b4). https://doi.org/10.5281/zenodo.20766922

# %%
# Run this to install nGibbs! Then restart the kernel.
# Warning: it requires pytorch, which is a little large: ~300 MB for the CPU-only version.

try: 
    import nGibbs
except ImportError:
    ptt.install_nGibbs()

# --pre means pre-release! nGibbs is still in development.
# Out:
# nGibbs is already installed.

# %% [markdown]
# ## Part 1 - Kilauea melt inclusions
#
# ![Image of the 2018 Kilauea eruption](https://d9-wret.s3.us-west-2.amazonaws.com/assets/palladium/production/s3fs-public/styles/full_width/public/thumbnails/image/multimediaFile-2306.jpg?itok=4N8FjB4T)
#
# For the first part of this workshop we'll be using a dataset of olivine hosted melt inclusions from Kilauea, specifically from the Lower East Rift Zone (LERZ) eruption of 2018. These data were collected by Penny Wieser and the values included here have already been corrected for the influence of post-entrapment crystallization (Wieser et al. 2021; https://doi.org/10.1029/2020GC009364).

# %% [markdown]
# ### 1.1 - Getting up to speed with Python
#
# **Before we get into the thermodynamics, let's first make sure everyone is comfortable with the basics of Python. To start, we'll use Pandas to load in the PEC corrected olivine-hosted melt inclusion compositions from the 2018 eruption**

# %%
Kil = pd.read_excel('Kilauea_olivines.xlsx')
Kil.head()
# Out:
#          Label    SiO2   TiO2   Al2O3       FeO     Fe2O3    MnO    MgO  \
# 0   LLD_LL1_80  51.423  3.229  13.392   9.68660  1.899333  0.149  6.191
# 1  LLD_LL1_103  51.375  3.343  13.202  10.09460  1.979333  0.134  6.001
# 2  LLE_LL4_19b  50.793  2.550  13.523   9.63645  1.889500  0.179  7.432
# 3  LLE_LL4_19c  51.117  2.512  13.435   9.71890  1.905666  0.239  7.526
# 4  LLE_LL4_33b  51.649  2.758  13.747   9.63730  1.889666  0.282  6.020
#
#       CaO   Na2O    K2O   P2O5       H2O       CO2       Temp  \
# 0   9.859  2.636  0.675  0.337  0.533371  0.025772  1138.4391
# 1   9.729  2.602  0.635  0.364  0.546140  0.021389  1134.6201
# 2  10.594  2.303  0.429  0.378  0.500000  0.040292  1163.3832
# 3  10.170  2.435  0.382  0.276  0.500000  0.022817  1165.2726
# 4  10.397  2.435  0.496  0.347  0.500000  0.024655  1135.0020
#
#    SaturationP_bars_VESIcal  XH2O_fl_VESIcal
# 0                       420         0.132780
# 1                       360         0.160732
# 2                       640         0.082606
# 3                       370         0.132469
# 4                       420         0.115698

# %% [markdown]
# **Now let's practice some data handling and basic plotting. First examine the `Label` column in the dataset. You should see some samples which contain the code `LL8` in their Label. These are melt inclusions from lavas erupted in mid-July from what was originally termed 'Fissure 8'. Have a go isolating just these inclusions, creating a new dataframe called `LL8`.**
#
# **Once this is completed, use the code below to create a simple plot of MgO vs CaO for the melt inclusions, with the LL8 samples identifiable through a different color or symbol.**

# %%
LL8 = Kil.loc[Kil['Label'].str.contains("LL8")].reset_index(drop = True)

# %%
plt.figure(figsize = (5, 4))
plt.plot(Kil['MgO'], Kil['CaO'], 'ok', mfc = 'b', label = "All Data")
plt.plot(LL8['MgO'], LL8['CaO'], 'ok', mfc = 'r', label = "LL8")
plt.xlabel('MgO wt%')
plt.ylabel('CaO wt%')
plt.legend()

# %% [markdown]
# ### 1.2 - Melt inclusion saturation pressures
#
# Before we go any further I would recommend that all MacOS and Linux users run the following cell **twice**. This suppresses all outputs from the MELTS C code (which overwise all appears in the notebook). This is not an issue for Windows users.

# %%
import platform
if platform.system()=="Darwin" or platform.system() == "Linux":
    import sys
    import os
    sys.stdout = open(os.devnull, 'w')
    sys.stderr = open(os.devnull, 'w')

# %% [markdown]
# PetThermoTools provides you with 2 ways to calculate melt inclusion saturation pressures. Notably, in both methods you need to provide the CO$_2$ contents in wt% (combining the CO$_2$ contribute from both the melt phase and bubble if present).
#
# 1. Simple saturation pressure calculations - we can use the rhyolite-MELTS v1.2.0 model (Ghiorso and Gualda, 2015) to calculate saturation pressure assuming a known temperature (`T_fixed_C` - usually determined using an empirical, liquid-based thermometer). All solid phases are turned off for these calculations, allowing the system to only stabilze liquid and fluid phases. The system will then iterate pressure to find the point of volatile saturation for each composition provided. This should be relatively fast. **Run the cell below and examine the structure of the outputs.** This method is essentially the same as that used in VESIcal when the magmasat model is selected (Iacovino et al. 2021).

# %%
Sat_P = ptt.saturation_pressure(Model = "MELTSv1.2.0",
                                bulk = LL8,
                                P_init_bar = 1000,
                                T_fixed_C = LL8['Temp'])

Sat_P.head()
# Out:
# Completed 100.0 %
#     SiO2_Liq  TiO2_Liq  Al2O3_Liq   FeOt_Liq   MnO_Liq    MgO_Liq    CaO_Liq  \
# 0  50.857554  2.414620  12.845737  11.297028  0.213348   7.642640  11.198771
# 1  51.000035  2.368247  12.836974  11.335442  0.187387   7.702782  11.047831
# 2  51.210784  2.524405  12.968435  11.283730  0.151305   7.646877  10.492806
# 3  50.999298  2.507558  13.008644  11.285065  0.157282   7.648103  10.766872
# 4  49.571081  2.159078  11.980592  11.293353  0.253188  11.037615  10.181360
#
#    Na2O_Liq   K2O_Liq  P2O5_Liq   H2O_Liq   CO2_Liq  Fe3Fet_Liq       P_bar  \
# 0  2.194293  0.402769  0.245250  0.498449  0.000960    0.149892   57.861328
# 1  2.168899  0.403678  0.243204  0.498360  0.017938    0.149892  308.593750
# 2  2.285502  0.500700  0.217999  0.497714  0.031384    0.149892  507.812500
# 3  2.237789  0.432029  0.247869  0.497729  0.023381    0.149892  392.578125
# 4  2.234835  0.338913  0.260166  0.498402  0.002898    0.149892   83.007812
#
#      T_Liq_C
# 0  1168.0866
# 1  1169.3328
# 2  1168.4082
# 3  1168.4283
# 4  1236.5673

# %% [markdown]
# This works well when you simply want the saturation pressure. But what if you intend to run further calculations using these compositions? In that case, its more useful to use PetThermoTools to solve for both pressure and temperature.
#
# 2. Coupled saturation pressure and liquidus calculations - one of the advanatages of PetThermoTools compared to VESIcal is the ability to deal with solid-melt-fluid systems, rather than a 2-component melt-fluid system. This means we can provide an initial temperature (`T_init_C`) rather than a fixed temperature and the system with iteratively solve for both T & P, searching for the highest pressure at which volatie saturation occurs at the liquidus temperature. **Complete the cell below to calculate the saturation pressure and liquidus temperature of these melt inclusion compositions. Use the following cells below to plot the two different pressure estimates and two different temperature estimates against each other.**

# %%
Sat_PT = ptt.saturation_pressure(Model = "MELTSv1.2.0",
                                bulk = LL8,
                                P_init_bar = 1000,
                                T_init_C = LL8['Temp'] + 50)
# Out:
# Completed 100.0 %

# %%
f, a = plt.subplots(1,2, figsize = (8, 3.5))
a[0].plot(Sat_P['P_bar'], Sat_PT['P_bar'], 'ok')
a[0].set_ylabel('P (bar); P & T solved')
a[0].set_xlabel('P (bar); P only')

a[1].plot(Sat_P['T_Liq_C'], Sat_PT['T_Liq_C'], 'ok')
a[1].set_ylabel('T ($^o$C); P & T solved')
a[1].set_xlabel('T ($^o$C); P only')

f.tight_layout()

# %% [markdown]
# ### 1.3 - Equilibration calculations and output structure

# %% [markdown]
# What we can do, now that we have a composition, pressure, and temperature for each inclusion, is run a set of simple equilibration calculations. Given that we searched for the P & T conditions of volatile saturation at the liquidus above, what these calculations will hopefully show is that the system is almost entirely melt/liquid at these conditions with a small about of fluid and a single solid phase.
#
# **Run the `equilibrate_multi` function below and examine the outputs. Specifically have a look at the `mass_g` DataFrame. What is the liquidus phase for these compositions? Is this expected?**
#
# *nGibbs interjection: The speed of equilibrate_multi is massively improved by nGibbs, because the full thermodynamic calculations here require individual instances of MELTS to be initialized, and each in turn requires a costly liquidus-find / subsolidus initial guess. nGibbs evaluates everything in perfect parallel isolation, even below the liquidus. Therefore, there is no additional expense incurred by running multiple compositions, nor any relative speedup for calculations at a constant composition.*
#
# *Note also that nGibbs is not able to suppress phases at this time, and thus is not supported for the above ptt.saturation_pressure() function*

# %%
start_time = time()
equil = ptt.equilibrate_multi(Model = "MELTSv1.2.0",
                            bulk = LL8,
                            P_bar = Sat_PT['P_bar'].values,
                            T_C = Sat_PT['T_Liq_C'].values)
end_time_PTT = time()
print(f"PTT equilibration time: {end_time_PTT - start_time:.2f} seconds")

try:
    n_equil = ptt.equilibrate_multi(Model = "nMELTSv1.2.0NoProp", # No properties needed for this analysis
                                bulk = LL8,
                                P_bar = Sat_PT['P_bar'].values,
                                T_C = Sat_PT['T_Liq_C'].values)

    print(f"nGibbs equilibration time: {time() - end_time_PTT:.2f} seconds")
except:
    print("Install nGibbs above and restart to run nGibbs through PTT!")
# Out:
# Completed 68.08510638297872 %
# Completed 100.0 %
# PTT equilibration time: 69.23 seconds
# nGibbs equilibration time: 0.06 seconds

# %%
equil['mass_g']
# Out:
#       liquid1  olivine1    fluid1
# 0   99.961712  0.038288  0.000000
# 1   99.976194  0.023659  0.000147
# 2   99.969848  0.030048  0.000104
# 3   99.913376  0.086624  0.000000
# 4   99.961138  0.038792  0.000069
# 5   99.927622  0.072332  0.000045
# 6   99.941903  0.058097  0.000000
# 7   99.998674  0.001223  0.000103
# 8   99.958696  0.041135  0.000169
# 9   99.920826  0.079174  0.000000
# 10  99.969847  0.029964  0.000189
# 11  99.914907  0.085093  0.000000
# 12  99.902788  0.096410  0.000802
# 13  99.940629  0.059036  0.000335
# 14  99.922875  0.076738  0.000388
# 15  99.932912  0.066880  0.000208
# 16  99.992313  0.007687  0.000000
# 17  99.900332  0.098679  0.000989
# 18  99.920038  0.079336  0.000627
# 19  99.997908  0.002022  0.000070
# 20  99.995089  0.004861  0.000050
# 21  99.983059  0.016794  0.000148
# 22  99.894605  0.105047  0.000349
# 23  99.962461  0.037221  0.000318
# 24  99.912791  0.087018  0.000191
# 25  99.914958  0.084348  0.000694
# 26  99.998352  0.001566  0.000081
# 27  99.884780  0.115220  0.000000
# 28  99.904392  0.095296  0.000312
# 29  99.983523  0.016389  0.000088
# 30  99.910005  0.089771  0.000223
# 31  99.966093  0.033555  0.000352
# 32  99.942903  0.056865  0.000232
# 33  99.882342  0.117225  0.000433
# 34  99.967047  0.032776  0.000177
# 35  99.981666  0.018203  0.000131
# 36  99.995367  0.004614  0.000019
# 37  99.901159  0.098841  0.000000
# 38  99.996116  0.003695  0.000189
# 39  99.994944  0.005056  0.000000
# 40  99.962620  0.037341  0.000040
# 41  99.874987  0.124477  0.000536
# 42  99.980807  0.018912  0.000281
# 43  99.965894  0.033846  0.000260
# 44  99.974304  0.025333  0.000362
# 45  99.945165  0.054734  0.000101
# 46  99.939053  0.060866  0.000081

# %% [markdown]
# ## Part 2 - Crystallization calculations
#
# ### 2.1 - extracting a starting composition
#
# Now we've got the hang of how PetThermoTools works, and how the output structures are designed, let's have a go running some crystallization calculations. The first thing to do is identify a suitable starting composition. **Isolate the row in the `Kil` DataFrame corresponding to the highest MgO content melt inclusion and use the `.squeeze()` method to turn this into a Pandas Series.**

# %%
Kil_starting = Kil.loc[Kil['MgO'] == Kil['MgO'].max()].squeeze()

# %%
Kil_starting
# Out:
# Label                         LL8_610
# SiO2                           49.279
# TiO2                            2.023
# Al2O3                          10.983
# FeO                           9.63475
# Fe2O3                        1.889166
# MnO                             0.202
# MgO                            13.734
# CaO                             9.581
# Na2O                            1.991
# K2O                             0.337
# P2O5                            0.192
# H2O                               0.5
# CO2                          0.088678
# Temp                        1290.0534
# SaturationP_bars_VESIcal         1050
# XH2O_fl_VESIcal              0.058573
# Name: 80, dtype: object

# %% [markdown]
# Before we go any further let's also load in some matrix glass data from the 2018 Kilauea eruption (again from Wieser et al. 2021).

# %%
Kil_glass = pd.read_excel("Kilauea_glass.xlsx")
Kil_glass.head()
# Out:
#    Description Sample Name Fissure (eruption date)    Na2O    Al2O3    P2O5  \
# 0          NaN  LLE_LL4_G2    Fissure 8 (May 30th)  2.5120  13.0360  0.2689
# 1          NaN  LLE_LL4_G1    Fissure 8 (May 30th)  2.4681  12.8885  0.2652
# 2          NaN  LLf_LL8_g2    Fissure 8 (Mid July)  2.2884  13.0277  0.2068
# 3          NaN  LLf_LL8_g1    Fissure 8 (Mid July)  2.3660  13.1034  0.2329
# 4          NaN  LLf_LL7_G2     Fissure 8 (Aug 1st)  2.4155  13.2432  0.2393
#
#        CaO     K2O    TiO2     SiO2     MgO     FeOt     MnO
# 0  10.2471  0.5234  2.8773  50.6243  5.8471  11.8288  0.1830
# 1   9.9658  0.5305  2.8840  50.0975  5.8521  11.2897  0.1769
# 2  10.6820  0.4462  2.5827  50.1517  6.6763  11.2420  0.2141
# 3  10.7276  0.4822  2.5686  50.2523  6.4934  10.9155  0.1948
# 4  10.6298  0.4704  2.6104  51.1145  6.5764  11.1522  0.1738

# %% [markdown]
# ### 2.2 - Isobaric crystallization
#
# Likely the most common function used in PetThermoTools is the `isobaric_crystallisation` function (note that it is an 's' not a 'z' because I'm British). So let's learn how to use that!
#
# There are many options in the `isobaric_crystallization` function. We need to provide information about pressure (`P_bar`), the starting composition (`bulk`) and the thermodynamic model (`Model`). In addition, we need to specify temperature constraints, information about the oxygen fugacity of the system, and whether we wish to perform fractional or equilibrium crystallization. There are many other options, which you can learn about through our documentation.
#
# **Using the code below perform 4 equilibrium crystallization calculations at different pressures. Try running similar calculations using fractional crystallization instead.**

# %%
start_time = time()

isobars = [250,500,1000,2000]

isobaric = ptt.isobaric_crystallisation(Model = "MELTSv1.0.2",
                                        bulk = Kil_starting,
                                        P_bar = isobars,
                                        find_liquidus = True,
                                        T_end_C = 1050,
                                        dt_C = 2,
                                        label = "P_bar")

end_time_PTT = time()
print(f"MELTS 1.0.2 isobaric crystallisation time: {end_time_PTT - start_time:.2f} seconds")

try:
    n_isobaric = ptt.isobaric_crystallisation(Model = "nMELTSv1.0.2NoProp", # don't type NoProps (with an s, easy mistake) or it will silently route to full MELTSv1.0.2!
                                            bulk = Kil_starting,
                                            P_bar = isobars,
                                            find_liquidus = True,
                                            T_end_C = 1050,
                                            dt_C = 2,
                                            label = "P_bar")
    print(f"nMELTS 1.0.2 isobaric crystallisation time: {time() - end_time_PTT:.2f} seconds")
except:
    pass
# Out:
# A default timeout of 5 minutes has been specified. If you are not getting any results try increasing this using the timeout kwarg.
# Completed 100.0 %
# MELTS 1.0.2 isobaric crystallisation time: 13.55 seconds
# nMELTS 1.0.2 isobaric crystallisation time: 0.11 seconds

# %% [markdown]
# Use the cell below to examine the outputs (hint use `isobaric.keys()` to see how the different calculations are stored in the output dictionary).

# %%
ptt.phase_plot

# %%
# Let's plot the phase abundances calculated from MELTS and nGibbs!(This will error if you don't have nGibbs installed))
for P in isobars:
    fig, (ax_a, ax_b) = plt.subplots(2,1, figsize=(16, 5),
                                    sharex=True, constrained_layout=True)

    ptt.Plotting._draw_stack(ax_a, isobaric[f'P = {P:.1f} bars']['Conditions']['T_C'], isobaric[f'P = {P:.1f} bars']['mass_g']/100,
                    isobaric[f'P = {P:.1f} bars']['mass_g'].columns, colors=ptt.Plotting.melts_colors(), title=f'PetThermoTools MELTS 1.0.2 Kilauea at P = {int(P)} bars',
                    x_name= '')
    ptt.Plotting._draw_stack(ax_b, n_isobaric[f'P = {P:.1f} bars']['Conditions']['T_C'], n_isobaric[f'P = {P:.1f} bars']['mass_g']/100,
                    n_isobaric[f'P = {P:.1f} bars']['mass_g'].columns, colors=ptt.Plotting.melts_colors(), title=f'nGibbs MELTS 1.0.2 Kilauea at P = {int(P)} bars',
                    x_name= '')
    plt.show()

# %% [markdown]
# The liquidus is a bit high in the nGibbs version. More prominently, nGibbs seems reluctant to predict small amounts of phases, and therefore phases don't gradually pinch in and out at saturation like they should, instead nGibbs produces 'stairsteps' of phase accumulation at saturation, similar to what would be expected in many real world scenarios due supercooling past the saturation point due to the kinetic barrier to crystallisation/bubble nucleation. But in equilibrium thermodynamics, it is an error.

# %% [markdown]
# **Use the `ptt.harker()` function to plot the results. We can also plot the matrix glass data from Wieser et al. (2021) using this function. Are these calculations doing a good job? If you're waiting, try different H2O or fO2 settings, and/or try different thermodynamic models.**

# %%
ptt.harker(Results = isobaric, data = Kil_glass)
# Out:
# (<Figure size 960x900 with 9 Axes>,
#  array([[<Axes: xlabel='MgO', ylabel='SiO$_2$'>,
#          <Axes: xlabel='MgO', ylabel='TiO$_2$'>,
#          <Axes: xlabel='MgO', ylabel='Al$_2$O$_3$'>],
#         [<Axes: xlabel='MgO', ylabel='FeO$_t$'>,
#          <Axes: xlabel='MgO', ylabel='CaO'>,
#          <Axes: xlabel='MgO', ylabel='Na$_2$O'>],
#         [<Axes: xlabel='MgO', ylabel='K$_2$O'>, <Axes: >, <Axes: >]],
#        dtype=object))

# %% [markdown]
# ## Part 3 - Phase Diagrams
#
# One interesting observation from the Hawaiian islands is that high-MgO orthopyroxene crystals are sometimes observed in lavas from the Loa trend (Mauna Loa, Hualalai, etc.) but these are rare or completely absent in samples from the Kea trend (Kilauea, Mauna Kea, Haleakala, etc.). The question becomes, is this something we can predict through thermodynamics, given that there are subtle differences in the major element composition of primary melts from each trend (see Fig. 8a in Wieser et al. 2025 for more details; https://doi.org/10.1007/s00445-025-01869-2).
#
# **Using the Kilauea starting composition we defined earlier calculate and plot the phase diagram for this composition at pressures between 250 and 5000 bar and temperatures between 1100 and 1400 Celsius (hint, use `np.linspace`)**

# %%
begin_time = time()
PD_Kil = ptt.phaseDiagram_calc(Model = "MELTSv1.2.0",
                                bulk = Kil_starting,
                                T_C = np.linspace(1100,1400,20),
                                P_bar = np.linspace(250,5000,20),
                                refine = 2,
                                i_max = 3)

print(f"Phase diagram calculation time: {time() - begin_time:.2f} seconds")
# Out:
# Attempt 0
# Performing another 343 calculations with interpolation used to calculate 778 points.
# Attempt 0
# Attempt 1
# Attempt 2
# Attempt 3
# Performing another 773 calculations with interpolation used to calculate 3635 points.
# Attempt 0
# Attempt 1
# Phase diagram calculation time: 157.59 seconds

# %%
ptt.plot_phaseDiagram(Combined = PD_Kil)
# Out:
# (<Figure size 1000x600 with 2 Axes>,
#  array([<Axes: xlabel='Temperature ($\\degree$C)', ylabel='Pressure (bar)'>,
#         <Axes: >], dtype=object))

# %%
begin_time = time()
nPD_Kil = ptt.phaseDiagram_calc(Model = "nMELTSv1.2.0",
                                bulk = Kil_starting,
                                T_C = np.linspace(1100,1400,20),
                                P_bar = np.linspace(250,5000,20),
                                refine = 2,
                                i_max = 10
                                )

print(f"nGibbs Phase diagram calculation time: {time() - begin_time:.2f} seconds")
# Out:
# nGibbs Phase diagram calculation time: 1.64 seconds

# %%
ptt.plot_phaseDiagram(Combined = nPD_Kil)
# Out:
# (<Figure size 1000x600 with 2 Axes>,
#  array([<Axes: xlabel='Temperature ($\\degree$C)', ylabel='Pressure (bar)'>,
#         <Axes: >], dtype=object))

# %%
ptt.plot_phaseDiagram_multi({'nGibbs': nPD_Kil, 'rhyolite-MELTS v1.0.2': PD_Kil})
# Out:
# (<Figure size 1200x1200 with 3 Axes>,
#  [<Axes: title={'center': 'nGibbs'}, xlabel='Temperature ($\\degree$C)', ylabel='Pressure (bar)'>,
#   <Axes: title={'center': 'rhyolite-MELTS v1.0.2'}, xlabel='Temperature ($\\degree$C)', ylabel='Pressure (bar)'>,
#   <Axes: >])

# %% [markdown]
# **Do the same calculation using this primary melt composition from Mauna Loa from Wieser et al. (2025). Do you notice any differences in the pressure and temperature of orthopyroxene stability?**

# %%
# Mauna Loa estimated primary melt composition from Wieser et al. 2025
ML_starting = {
    'SiO2_Liq': 48.5858,
    'TiO2_Liq': 1.4381,
    'Al2O3_Liq': 9.73,
    'FeOt_Liq': 10.144,        
    'MgO_Liq': 20.0,
    'CaO_Liq': 7.2186,
    'Na2O_Liq': 1.7327,
    'K2O_Liq': 0.3227,
    #'Cr2O3_Liq': 0.0702, # nGibbs accepts chomium greater than 0.1 or exactly 0.
    'H2O_Liq': 0.2,
    'Fe3Fet_Liq': 0.12       
}

# %%
start_time = time()
PD_ML = ptt.phaseDiagram_calc(Model = "MELTSv1.0.2",
                                bulk = ML_starting,
                                T_C = np.linspace(1100,1400,20),
                                P_bar = np.linspace(250,5000,20),
                                refine = 2,
                                i_max = 3)
print(f"Phase diagram calculation time: {time() - start_time:.2f} seconds")
# Out:
# Attempt 0
# Performing another 223 calculations with interpolation used to calculate 898 points.
# Attempt 0
# Attempt 1
# Attempt 2
# Attempt 3
# Performing another 506 calculations with interpolation used to calculate 3902 points.
# Attempt 0
# Attempt 1
# Phase diagram calculation time: 141.71 seconds

# %%
ptt.plot_phaseDiagram(Combined = PD_ML)
# Out:
# (<Figure size 1000x600 with 2 Axes>,
#  array([<Axes: xlabel='Temperature ($\\degree$C)', ylabel='Pressure (bar)'>,
#         <Axes: >], dtype=object))

# %%
start_time = time()
nPD_ML = ptt.phaseDiagram_calc(Model = "nMELTSv1.0.2",
                                bulk = ML_starting,
                                T_C = np.linspace(1100,1400,20),
                                P_bar = np.linspace(250,5000,20),
                                #fO2_offset = -1,
                                refine = 2,
                                i_max = 10)
print(f"Phase diagram calculation time: {time() - start_time:.2f} seconds")
# Out:
# Phase diagram calculation time: 1.50 seconds

# %%
ptt.plot_phaseDiagram(Combined = nPD_ML)
# Out:
# (<Figure size 1000x600 with 2 Axes>,
#  array([<Axes: xlabel='Temperature ($\\degree$C)', ylabel='Pressure (bar)'>,
#         <Axes: >], dtype=object))

# %% [markdown]
# Finally, we can use the following code to extract information from the phase diagrams. In this case let's look directly at the mass of orthopyroxene in each calculation:

# %%
X_Kil, Y_Kil, Z_Kil = ptt.make_grid_variables_from_phase_diagram(
    Results = PD_Kil,
    x_col = "T_C",
    y_col = "P_bar",
)

X_ML, Y_ML, Z_ML = ptt.make_grid_variables_from_phase_diagram(
    Results = PD_ML,
    x_col = "T_C",
    y_col = "P_bar",
)

X_nKil, Y_nKil, Z_nKil = ptt.make_grid_variables_from_phase_diagram(
    Results = nPD_Kil.sort_values(['T_C', 'P_bar'], ascending=[True, True]),
    x_col = "T_C",
    y_col = "P_bar",
)

X_nML, Y_nML, Z_nML = ptt.make_grid_variables_from_phase_diagram(
    Results = nPD_ML.sort_values(['T_C', 'P_bar'], ascending=[True, True]),
    x_col = "T_C",
    y_col = "P_bar",
)

# %%
f, a = plt.subplots(
    2, 2, figsize=(10, 4), sharex=True, sharey=True
)

# ------------------------------------------------
# Panel 1: Opx in Kilauea
pcm1 = a[0][0].pcolormesh(
    X_Kil, Y_Kil, Z_Kil["mass_g_Opx"],
    shading="auto",
    cmap="viridis", vmin=0, vmax=10,
)
a[0][0].set_title("Kilauea")
# a[0][0].set_xlabel("T (°C)")
a[0][0].set_ylabel("P (bar)")
f.colorbar(pcm1, ax=a[0][0], label="% Opx")

# ------------------------------------------------
# Panel 2: Opx in Mauna Loa

pcm2 = a[0][1].pcolormesh(
    X_ML, Y_ML, Z_ML["mass_g_Opx"],
    shading="auto",
    cmap="viridis", vmin=0, vmax=10,
)
a[0][1].set_title("Mauna Loa")
# a[0][1].set_xlabel("T (°C)")
f.colorbar(pcm2, ax=a[0][1], label="% Opx")

# ------------------------------------------------
# Panel 3: Opx in n-Kilauea
pcm1 = a[1][0].pcolormesh(
    X_nKil, Y_nKil, Z_nKil["mass_g_Opx"],
    shading="auto",
    cmap="viridis", vmin=0, vmax=10,
)
a[1][0].set_title("nGibbs Kilauea")
a[1][0].set_xlabel("T (°C)")
a[1][0].set_ylabel("P (bar)")
f.colorbar(pcm1, ax=a[1][0], label="% Opx")

# ------------------------------------------------
# Panel 3: Opx in n-Mauna Loa

pcm2 = a[1][1].pcolormesh(
    X_nML, Y_nML, Z_nML["mass_g_Opx"],
    shading="auto",
    cmap="viridis", vmin=0, vmax=10,
)
a[1][1].set_title("nGibbs Mauna Loa")
a[1][1].set_xlabel("T (°C)")
f.colorbar(pcm2, ax=a[1][1], label="% Opx")

f.tight_layout()

# %%
start_time = time()
base_kwargs = dict(Model = "nMELTSv1.0.2NoProp",
                                bulk = ML_starting,
                                T_C = np.linspace(1100,1600,20),
                                P_bar = np.linspace(250,5000,20),
)
print(f"nGibbs animated Phase Diagram calculation")

frame_kwargs = {'fO2_offset': np.linspace(-5,5,11)}

ani = ptt.animate_phaseDiagram(base_kwargs, frame_kwargs, P_units="bar", T_units="C",
                         label=True, colormap=None, interval=500)
plt.close() # Don't show static plot in notebook
ani.save(filename="phase_diagram.gif", writer="pillow")
from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# nGibbs animated Phase Diagram calculation
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgdb39d87a19da4ced8e136f8e629d328f">
#   <div class="anim-controls">
#     <input id="_anim_sliderdb39d87a19da4ced8e136f8e629d328f" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animdb39d87a19da4ced8e136f8e629d328f.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animdb39d87a19da4ced8e136f8e629d328f.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animdb39d87a19da4ced8e136f8e629d328f.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animdb39d87a19da4ced8e136f8e629d328f.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animdb39d87a19da4ced8e136f8e629d328f.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animdb39d87a19da4ced8e136f8e629d328f.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animdb39d87a19da4ced8e136f8e629d328f.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animdb39d87a19da4ced8e136f8e629d328f.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animdb39d87a19da4ced8e136f8e629d328f.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animdb39d87a19da4ced8e136f8e629d328f.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectdb39d87a19da4ced8e136f8e629d328f"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_db39d87a19da4ced8e136f8e629d328f"
#              >
#       <label for="_anim_radio1_db39d87a19da4ced8e136f8e629d328f">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_db39d87a19da4ced8e136f8e629d328f"
#              checked>
#       <label for="_anim_radio2_db39d87a19da4ced8e136f8e629d328f">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_db39d87a19da4ced8e136f8e629d328f"
#              >
#       <label for="_anim_radio3_db39d87a19da4ced8e136f8e629d328f">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdb39d87a19da4ced8e136f8e629d328f";
#     var slider_id = "_anim_sliderdb39d87a19da4ced8e136f8e629d328f";
#     var loop_select_id = "_anim_loop_selectdb39d87a19da4ced8e136f8e629d328f";
#     var frames = new Array(11);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjYsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvq6yFwwAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQABAABJR

# %%
# 1. Define variables (change these to your needs)
REPO_URL="https://github.com/gleesonm1/PetThermoTools.git"
SUBFOLDER_PATH="Workshops/Jan_2026_Online"
BRANCH="master" 

# 2. Initialize a new local repository
# !git init ptt_folder_mon
# %cd ptt_folder_mon

# 3. Enable sparse-checkout
# !git remote add -f origin $REPO_URL
# !git config core.sparseCheckout true

# 4. Define which folder to pull
# !echo $SUBFOLDER_PATH >> .git/info/sparse-checkout

# 5. Pull the content
# !git pull origin $BRANCH
# Out:
# Initialized empty Git repository in /Users/gleesonm/Library/CloudStorage/GoogleDrive-gleesonm@berkeley.edu/My Drive/2022/GitHub/PetThermoTools_worshop_Jan2026/repo_folder_mon/.git/
# /Users/gleesonm/Library/CloudStorage/GoogleDrive-gleesonm@berkeley.edu/My Drive/2022/GitHub/PetThermoTools_worshop_Jan2026/repo_folder_mon
# Updating origin
# remote: Enumerating objects: 3438, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 3438 (delta 60), reused 61 (delta 37), pack-reused 3327 (from 2)
# Receiving objects: 100% (3438/3438), 108.16 MiB | 1.69 MiB/s, done.
# Resolving deltas: 100% (2040/2040), done.
# From https://github.com/gleesonm1/PetThermoTools
#  * [new branch]      master     -> origin/master
#  * [new tag]         v0.3.11    -> v0.3.11
#  * [new tag]         v0.0.1     -> v0.0.1
#  * [new tag]         v0.0.10    -> v0.0.10
#  * [new tag]         v0.0.11    -> v0.0.11
# ...
